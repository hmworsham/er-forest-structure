# %% [markdown]
# # Cleaning East River Stem Geolocation Shapefiles
# **Author:** 'Marshall Worsham' <br>
# **Creation Date:** '09/21/2020' <br>
# **Revision Date:** '12/22/2020' <br>
#
# ---
#
# ## Table of Contents
#
# 1 - [Front matter](#front)<br>
# 2 - [Import stem geolocation shapefiles](#import)<br>
#
# ---

# %% [markdown]
# ## Front matter<a id='front'></a>
#
# This notebook contains markdown and code for post-processing point shapefiles generated from Trimble Geo7X GPS acquisitions in the East River domain. The input is a set of shapefiles containing tree geolocation points, one set for each site in the watershed where stem geolocations were acquired from 2018–2020.
#
# The script appends the `Site` name and `subdirectory` to each shapefile name, then selects all projected point shapefiles, groups them by `Site` name, and merges points from the same site. It then filters out undesired points (e.g., plot corners and plot edges)
#
# The script was developed in `Python 3.8.2` on a Macbook Pro 2014 running OSX 10.14.6.

# %% [markdown]
# ### Libraries<a id='libraries'></a>

# %%
import os
import pandas as pd
import geopandas as gpd
import numpy as np
import math
import re
from matplotlib import pyplot as plt
from os.path import join, getsize
# %matplotlib inline
import ipywidgets as widgets
from ipywidgets import interact, interactive, fixed, interact_manual

# %% [markdown]
# ### Define the working directories and list contents

# %%
directory = os.sep.join(['/Volumes', 'GoogleDrive', 'My Drive', 'Research', 'RMBL', 'Working_Files', 'Forest_Inventory_Dataset'])
source_dir = os.sep.join([directory, 'Source'])
scratch_dir = os.sep.join([directory, 'Scratch'])
out_dir = os.sep.join([directory, 'Output'])
# stem_dir = os.sep.join([scratch_dir, 'GPS_Data_2021_MERGEDBYPLOT'])
stem_dir = os.sep.join(['..', 'data', 'intermediate'])
os.listdir(stem_dir)
# Out:
# ['GPS_Data_2021_MERGEDBYPLOT_ER-BME1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN2.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-SWR1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_WG-WGM1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-UC1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-BME1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-EMN1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-GT1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN2.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SR-PVG1.dbf',
#  '.DS_Store',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-APL1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR3.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN2.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVS1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-APL1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES2.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR3.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-APL1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SR-PVG1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES3.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR3.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN2.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_SR-PVG1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-GT1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-EMN1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-EMN1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-GT1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-BME1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-UC1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-BME1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-SWR1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN2.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_WG-WGM1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-UC1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN2.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-SWR1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_WG-WGM1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN2.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVS1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVN1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES3.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVS1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES2.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-APL1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES2.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES1.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-CVS1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES3.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES1.shp',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES2.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-CAR3.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-NES3.shx',
#  'GPS_Data_2021_MERGEDBYPLOT_SR-PVG1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-UC1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_CC-EMN1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_ER-GT1.prj',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_WG-WGM1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_SG-SWR1.dbf',
#  'GPS_Data_2021_MERGEDBYPLOT_XX-PLN2.dbf']

# %% [markdown]
# ### Set pandas view to max rows and columns

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %% [markdown]
# ## Import stem geolocation shapefiles<a id='import'></a>

# %%
# import the temp geodataframes from the append operations
stem_files = os.listdir(stem_dir)
stem_sf = [s for s in stem_files if s.endswith('.shp')]
stem_paths = [stem_dir + s for s in stem_sf]
appd_gpdf = []
for sf in stem_sf:
    gpdf = gpd.read_file(os.sep.join([stem_dir, sf]))
    appd_gpdf.append(gpdf)

# %%
# Set a figure frame
plt.figure(figsize = (30,15))

# Plot the dataframes in sequence on the figure frame
for i, gpdf in enumerate(appd_gpdf):
    
    # create subplot axes in a 5x3 grid
    ax = plt.subplot(5, 4, i + 1) # nrows, ncols, axes position
    
    # set title
    ax.set_title(gpdf.Site[0])
    
    # plot the plot on these axes
    gpdf.plot(ax=ax)

plt.tight_layout();

# %% [markdown]
# ## Some functions to interact

# %%
# print ordered list of new geodataframes
print([i for i in stem_files if i.endswith('.shp')])
# Out:
# ['GPS_Data_2021_MERGEDBYPLOT_ER-BME1.shp', 'GPS_Data_2021_MERGEDBYPLOT_CC-CVN2.shp', 'GPS_Data_2021_MERGEDBYPLOT_CC-CVN1.shp', 'GPS_Data_2021_MERGEDBYPLOT_ER-APL1.shp', 'GPS_Data_2021_MERGEDBYPLOT_XX-CAR1.shp', 'GPS_Data_2021_MERGEDBYPLOT_XX-CAR3.shp', 'GPS_Data_2021_MERGEDBYPLOT_SR-PVG1.shp', 'GPS_Data_2021_MERGEDBYPLOT_ER-GT1.shp', 'GPS_Data_2021_MERGEDBYPLOT_CC-EMN1.shp', 'GPS_Data_2021_MERGEDBYPLOT_SG-SWR1.shp', 'GPS_Data_2021_MERGEDBYPLOT_XX-PLN2.shp', 'GPS_Data_2021_MERGEDBYPLOT_WG-WGM1.shp', 'GPS_Data_2021_MERGEDBYPLOT_CC-UC1.shp', 'GPS_Data_2021_MERGEDBYPLOT_XX-PLN1.shp', 'GPS_Data_2021_MERGEDBYPLOT_CC-CVS1.shp', 'GPS_Data_2021_MERGEDBYPLOT_SG-NES2.shp', 'GPS_Data_2021_MERGEDBYPLOT_SG-NES3.shp', 'GPS_Data_2021_MERGEDBYPLOT_SG-NES1.shp']

# %%
# # function to interact with dataframe
# def fh_interact(df):
#     '''
#     outputs sliders that show rows and cols of df
#     '''
#     def peek(row = 1, col = 0):
#         return df.iloc[row: row+10, col: col+10]
#     interact(peek, row = (0, len(df), 5), col = (0, len(df.columns) - 6))
#     print('({} rows, {} columns total'.format(df.shape[0], df.shape[1]))

# %% [markdown]
# ## Define a function to generate new points based on geotag association notes in field notebooks and GPS units
# For some trees that were growing very closely together, we did not geotag each tree individually with the GPS unit in order to save battery and complete the inventory. Instead, we left directional notes in the `Other` or `Other2` field. These comments had the format, e.g. "6030 0.4m NW". This indicated that for a given geotagged tree, #6030 was an ungeotagged associated tree standing 0.4m to the northwest of the geotagged tree. We define a function below that uses those notes to construct geolocation points for the trees that were associated through these notes.

# %%
def makenewpoint(associationdf, reftag, targtag, direction, distance):
    '''
    Creates new point geometries for stems that weren't geotagged but have directional and distance references in notes. 
    Inputs:
        - gpdf: geodataframe storing geometry and association data
        - reftag: an integer indicating the reference (geotagged) tree tag number
        - targtag: an integer indicating the target (untagged associated) tree tag number
        - dir: string indicating cardinal direction from reference to target (e,n,w,s,ne,nw,sw,se) noted in 'Other' or 'Other2' field
        - distance: float indicating distance from reference to target noted in 'Other' or 'Other2' field
    Returns:
        - geopandas entry with point geometry
    '''

    # Conversion from degrees to radians
    rad = np.pi/180

    # Calculate cardinal directions as radian angles from east-facing origin
    erad = rad*0.00001
    nrad = rad*90
    wrad = rad*180
    srad = rad*270
    nerad = rad*45
    nwrad = rad*135
    swrad = rad*225
    serad = rad*315

    # Define radian direction based on cardinal direction input
    if not isinstance(direction, float):
        if direction.lower() == 'e':
            raddir = erad
        elif direction.lower() == 'n':
            raddir = nrad
        elif direction.lower() == 'w':
            raddir = wrad
        elif direction.lower() == 's':
            raddir = srad
        elif direction.lower() == 'ne':
            raddir = nerad
        elif direction.lower() == 'nw':
            raddir = nwrad
        elif direction.lower() == 'sw':
            raddir = swrad
        elif direction.lower() == 'se':
            raddir = serad
    # elif isinstance(direction, float):
    else:
        intrad = rad*direction
        raddir = intrad

    # Find x,y coordinates of reference tag number
    refcoords = associationdf[associationdf['Tag_Number'] == reftag].geometry
    x = refcoords.x
    y = refcoords.y

    # Calculate coordinates of target tag number
    x_prime = distance * np.cos(raddir) + x
    y_prime = distance * np.sin(raddir) + y
    
    # print(targtag, raddir, x, y, x_prime, y_prime, sep='\n')

    # Create a new temp gpdf from new geometries   
    new_gdf = gpd.GeoDataFrame(geometry = gpd.points_from_xy(x_prime, y_prime, crs = 'epsg:32612'))
    new_gdf['Tag_Number'] = targtag
    new_gdf['Comment'] = 'Point generated post-campaign from geotag association note'
    new_gdf['Geotag_Association'] = reftag
    new_gdf = new_gdf[['Tag_Number', 'Comment', 'Geotag_Association', 'geometry']]

    return new_gdf

# %% [markdown]
# ---
# ## Cleaning function

# %%
def cleansf(geodf, invsheet_id):
    '''
    TODO
    '''
    
    # Prep inventory datasheet for merge
    invsheet = f'https://docs.google.com/spreadsheets/d/{invsheet_id}/export?format=csv'
    invdata = pd.read_csv(invsheet)
    invdata['Tag_Number'] = pd.to_numeric(invdata['Tag_Number'], downcast='integer')
    
    # Prep points geodataframe for merge
    gcrs = geodf.crs
    geodf = pd.DataFrame(geodf)
    geodf['Tag_Number'] = pd.to_numeric(geodf['Other'], downcast='integer')

    # Merge the inventory and points dataframes
    merged = invdata.merge(geodf, on='Tag_Number', how='left')
    merged['Geotag_Association_Ref'] = pd.to_numeric(merged['Geotag_Association_Ref'], downcast='integer')
    merged = gpd.GeoDataFrame(merged, crs = gcrs, geometry = merged['geometry'])

    def getinputs(df, col, testcol='Geotag_Association_Ref'):
            return [df[col][i] for i in df.index if pd.notnull(df[testcol][i])]

    reftags = pd.to_numeric(getinputs(merged, 'Geotag_Association_Ref'), downcast='integer')
    targtags = pd.to_numeric(getinputs(merged, 'Tag_Number'), downcast='integer')
    dirs = getinputs(merged, 'Geotag_Association_Dir')
    dists = getinputs(merged, 'Geotag_Association_Dist')

    assert len(reftags) == len(targtags) == len(dirs) == len(dists)
    
    newpoints_ls = []
    #iterators = zip(reftags, targtags, dirs, dists)
    
    for targtag, reftag, dirc, dist in zip(targtags, reftags, dirs, dists):
        if (pd.notnull(dirc) | pd.notnull(dist)):
            newpoint = makenewpoint(merged, reftag, targtag, dirc, dist)
            newpoints_ls.append(newpoint)
    
    geodfclean = geodf.append(newpoints_ls, ignore_index=True)
    geodfclean['Site'] = invdata['Site_Name'][0]
    geodfclean['Sp_Code'] = np.NaN
    if 'Comment' not in geodfclean:
        geodfclean['Comment'] = np.NaN
    if 'Geotag_Association' not in geodfclean:
        geodfclean['Geotag_Association'] = np.NaN
    geodfclean = geodfclean[[
        'Site',
        'Tag_Number',
        'Sp_Code',
        'Latitude',
        'Longitude',
        'GNSS_Heigh',
        'Horz_Prec',
        'Vert_Prec',
        'Std_Dev',
        'GPS_Time',
        'GPS_Date',
        'Rcvr_Type',
        'Corr_Type',
        'Max_PDOP',
        'Max_HDOP',
        'Geotag_Association',
        'Comment',
        'geometry'
        ]]

    clsv = geodfclean.sort_values(['Tag_Number', 'Horz_Prec'])
    dropidx = geodfclean[geodfclean.duplicated(subset='Tag_Number', keep='first')].index
    geodfclean.drop(dropidx, inplace=True)
    geodfclean.reset_index(drop=True, inplace = True)

    geodfclean.replace(['', 'None'], np.nan, inplace = True)
    geodfclean=gpd.GeoDataFrame(geodfclean, crs=gcrs, geometry=geodfclean.geometry)
    geodfclean['Tag_Number'] = pd.to_numeric(geodfclean['Tag_Number'], downcast='integer')
    geodfclean['Geotag_Association'] = pd.to_numeric(geodfclean['Geotag_Association'], downcast='integer')

    return geodfclean

# %%
def getshid(url):
    return(url.split('/')[5].split('?')[0])

# %%
cccvn1 = getshid('https://docs.google.com/spreadsheets/d/1beSW4hYnmxxC2X3yPkKJsqP3gg33RH6qbB9DvVVcnUE?authuser=worsham%40berkeley.edu&usp=drive_fs')
cccvn2 = getshid('https://docs.google.com/spreadsheets/d/1KqNXUVWMN76Wu3emK11ZC0JWEGafcARoyVFIXHWx7EI?authuser=worsham%40berkeley.edu&usp=drive_fs')
cccvs1 = getshid('https://docs.google.com/spreadsheets/d/1KpHlGMiAbLpT8QIccMEAgAQ2vkRZq_5d9i0jRm-S7OE?authuser=worsham%40berkeley.edu&usp=drive_fs')
ccemn1 = getshid('https://docs.google.com/spreadsheets/d/1CyY3OfzBoFVHCu1QhchbKn7Y8g1uVMQJOQMFriynvSM?authuser=worsham%40berkeley.edu&usp=drive_fs')
sgnes1 = getshid('https://docs.google.com/spreadsheets/d/1veFBxhR0wD4Qu07ZYyNNQlzKg5J9YTNL8E1VML8u_gw?authuser=worsham%40berkeley.edu&usp=drive_fs')
sgnes3 = getshid('https://docs.google.com/spreadsheets/d/1v5oJcULvbW-IYfvfLVFuCzUIT5mTbwtfYNAorns1E5M?authuser=worsham%40berkeley.edu&usp=drive_fs')
srpvg1 = getshid('https://docs.google.com/spreadsheets/d/1zc-1B8T91BEd0tc1SvgUGFot-Dj6M02p1ZLoXYCPw2o?authuser=worsham%40berkeley.edu&usp=drive_fs')
xxpln1 = getshid('https://docs.google.com/spreadsheets/d/1VQ8bGxJACttKfQ0V4Hbg3HIIybRA5Pw8yBXUpD2Kv28?authuser=worsham%40berkeley.edu&usp=drive_fs')
xxpln2 = getshid('https://docs.google.com/spreadsheets/d/1q-wH_h-WbNHHqALjGv3KzaTKHfLuYkkTHR9uzMSPtcU?authuser=worsham%40berkeley.edu&usp=drive_fs')
sgnes2 = getshid('https://docs.google.com/spreadsheets/d/1s3MBQ5UMkMlyjV1YVecahvDHZ_Oyy0EyCYSveYkg_ig?authuser=worsham%40berkeley.edu&usp=drive_fs')
ccuc1 = getshid('https://docs.google.com/spreadsheets/d/1cNTpoD0S0X1rnptilEfLWDyYxaEhrwBuIbD7XlPC3L4?authuser=worsham%40berkeley.edu&usp=drive_fs')
erbme1 = getshid('https://docs.google.com/spreadsheets/d/1FDIBHXM0Zg_X_vkc_Ryc7v4P7L-7mtdbRI53ucaPgaw?authuser=worsham%40berkeley.edu&usp=drive_fs')
sgswr1 = getshid('https://docs.google.com/spreadsheets/d/1EcrhpG2qMAwvTYdAH9J9Gqriuuiwe1PBAUAyLXnAgts?authuser=worsham%40berkeley.edu&usp=drive_fs')
wgwgm1 = getshid('https://docs.google.com/spreadsheets/d/1mlF02kwTQLeCzf9jnSpFL48cxiQdEg7elwr4tsAOPXU?authuser=worsham%40berkeley.edu&usp=drive_fs')
erapl1 = getshid('https://docs.google.com/spreadsheets/d/1CxcYtqh7jplLEr9fx7u2jOIAiTkbebrX8_M3330Abxk?authuser=worsham%40berkeley.edu&usp=drive_fs')
xxcar3 = getshid('https://docs.google.com/spreadsheets/d/1Oxz-exmF11akp2IEkO3rG1ZyIggHDrSyznZFKEpa2HI?authuser=worsham%40berkeley.edu&usp=drive_fs')
xxcar1 = getshid('https://docs.google.com/spreadsheets/d/1NJVvhj4gnI5e3hdVvwuSiC7NyIWXGwVUgZGc3Gv9Fko?authuser=worsham%40berkeley.edu&usp=drive_fs')

# %%
# All observations in 2021
#invsheets = [xxpln1, sgnes2, cccvs1, xxpln2, srpvg1, sgnes3, ergt1, ccuc1, xxcar3, sgnes1, cccvn2, xxcar1, cccvn1, ccemn1, erbme1, sgswr1, wgwgm1, erapl1]
#idxs = list(range(0, len(invsheets)))

# %%
# All observations from new sites in 2021
invsheets = [cccvs1, xxpln2, srpvg1, sgnes3, xxcar3, sgnes1, cccvn2, xxcar1, cccvn1, ccemn1]
idxs = [2, 3, 4, 5, 8, 9, 10, 11, 12, 13]
geodfs = [appd_gpdf[i] for i in idxs]

# %%
# Observations missed in 2020 and taken in 2021
# invsheets = [xxpln1, sgnes2, ccuc1, sgswr1, wgwgm1]
# idxs = [0,1,7,15,16]
# geodfs = [appd_gpdf[i] for i in idxs]

# %%
appd_gpdf[10]
# Out:
#                                       Filename Study_Orga Study_Loca  \
# 0    KATZJ062214A_XX-PLN2_Student__Project.shp       None       None
# 1    KATZJ062212A_XX-PLN2_Student__Project.shp       None       None
# 2    KATZJ062212A_XX-PLN2_Student__Project.shp       None       None
# 3    KATZJ062212A_XX-PLN2_Student__Project.shp       None       None
# 4    KATZJ061412A_XX-PLN2_Student__Project.shp       None       None
# 5    KATZJ061412A_XX-PLN2_Student__Project.shp       None       None
# 6    KATZJ061412A_XX-PLN2_Student__Project.shp       None       None
# 7    KATZJ061412A_XX-PLN2_Student__Project.shp       None       None
#
# 11        None       None               9308   abla       5.3       2.0
# 12        None       None               9310   abla       2.6       1.8
# 13        None       None               9312   abla       2.9       1.6
# 14        None       None               9313   abla       5.1       2.7
# 15        None       None               5650   abla       3.7       2.4
# 16        None       None               9315   abla       4.0       2.1
# 17        None       None               9317   abla       3.1       2.2
# 18        None       None               9319   abla       4.0       2.7
# 19        None       None               9322   abla       4.5       3.6
# 20        None       None               5933   None       4.2       1.9
# 21        None       None               9514   None      24.4      12.2
# 22        None       None               5931   None       4.0       2.2
# 23        None       None               5925   None       2.6       1.5
# 24        None       None               5924   None       2.6       1.5
# 25        None       None               5932   None       4.2       3.7
# 26        None       None               9528   None       3.9       1.8
# 27        None       None               9531   None       2.9       2.2
# 28        None       None               5629   None       5.3       2.0
# 29        None       None               9544   None       2.8       1.6
# 30        None       None               5909   None       6.3       3.8
# 31        None       None               5918   None       5.7       3.3
# 32        None       None               5920   None       2.8       1.7
# 33        None       None               5922   None       3.8       3.3
# 34        None       None               5923   None       6.2       2.0
# 35        None       None               5939   None       3.1       1.7
# 36        None       None               9509   None       5.4       3.7
# 37        None       None               5910   None       4.1       2.8
# 38        None       None               9552   None       7.0       2.1
# 39        None       None               9553   None       3.5       1.6
# 40        None       None               5905   None       3.1       1.6
# 41        None       None               5636   None       2.9       1.7
# 42        None       None               5683   None       6.0       3.7
# 43        None       None               5681   None       4.6       2.1
# 44        None       None               9589   None       3.8       1.7
# 45        None       None               9596   None       8.6       3.0
# 46        None       None               5815   None       8.3       3.5
# 47        None       None               9616   None       3.8       2.1
# 48        None       None               5812   None       3.4       1.5
# 49        None       None               5811   None       4.2       2.9
# 50        None       None               9600   None       3.2       1.4
# 51        None       None               5806   None       3.3       1.6
# 52        None       None               9604   None       3.5       1.5
# 53        None       None               5914   None       6.8       2.2
# 54        None       None               591r   None       5.5       1.9
# 55        None       None               9614   None       5.1       1.7
# 56        None       None               5809   None       3.3       1.5
# 57        None       None               5810   None       4.7       2.1
# 58        None       None               9631   None       3.2       1.8
# 59        None       None               5816   None      35.4      27.0
# 60        None       None               9634   None       3.2       1.5
# 61        None       None               9632   None       2.7       1.5
# 62        None       None               9633   None       4.8       2.9
# 63        None       None               9635   None       5.6       1.9
# 64        None       None               5821   None       3.3       2.2
# 65        None       None               5818   None       3.9       2.3
# 66        None       None               5820   None       3.3       1.8
# 67        None       None               9643   None       4.6       1.9
# 68        None       None               9644   None       2.7       1.2
# 69        None       None               5825   None       3.3       2.0
# 70        None       None               5824   None       9.9       7.5
# 71        None       None               9652   None       5.5       3.6
# 72        None       None               5827   None       3.6       2.2
# 73        None       None               5834   None       2.8       1.7
# 74        None       None               5832   None       4.4       3.0
# 75        None       None               964r   None       3.5       2.7
# 76        None       None               5830   None      11.2       8.4
# 77        None       None               9659   None       4.1       2.7
# 78        None       None               9657   None       5.0       2.4
# 79        None       None               5651   abla      14.3       9.1
# 80        None       None               5652   abla       5.0       2.4
# 81        None       None               9324   abla     141.3      99.9
# 82        None       None               5654   abla       4.4       2.0
# 83        None       None               5656   abla       3.5       2.4
# 84        None       None               5655   abla      44.9      34.4
# 85        None       None               9330   abla       5.5       4.6
# 86        None       None               5657   unkn       4.5       1.9
# 87        None       None               5612   pien       3.8       2.4
# 88        None       None               5611   pien       4.7       3.1
# 89        None       None               9331   abla       4.5       2.3
# 90        None       None               9334   abla       3.7       2.2
# 91        None       None               9336   abla       4.8       3.8
# 92        None       None               5616   pien       3.9       2.6
# 93        None       None               9338   abla       3.9       2.2
# 94        None       None               5672   pien       3.1       1.2
# 95        None       None               5673   abla       6.4       1.5
# 96        None       None               9339   abla       3.9       1.9
# 97        None       None               5658   abla       7.7       4.9
# 98        None       None               5671   pien      19.2       3.7
# 99        None       None               5660   pien       9.3       1.9
# 100       None       None               5659   pien       3.7       1.4
# 101       None       None               5661   pico       4.4       1.6
# 102       None       None               5617   pien       4.6       1.6
# 103       None       None               9344   abla       5.0       1.4
# 104       None       None               5662   pico       3.3       1.1
# 105       None       None               9346   abla       5.8       5.2
# 106       None       None               5664   pico       5.4       1.6
# 107       None       None               5619   pien       6.8       1.5
# 108       None       None               5663   pien       6.5       1.5
# 109       None       None               9349   abla       5.1       1.8
# 110       None       None               5665   abla       7.4       1.9
# 111       None       None               9353   pico       8.1       2.4
# 112       None       None               9354   pico      11.8       3.1
# 113       None       None               9352   pico       4.9       1.4
# 114       None       None               9359   abla       3.8       1.3
# 115       None       None               5670   pien       3.8       1.3
# 116       None       None               5669   pico     141.3      99.9
# 117       None       None               5668   abla       3.9       1.4
# 118       None       None               5624   pien       3.8       1.4
# 119       None       None               9361   abla       4.7       1.6
# 120       None       None               5620   abla       3.6       1.8
# 121       None       None               5621   pien       4.6       1.8
# 122       None       None               5622   pien       3.3       1.8
# 123       None       None               9363   abla       5.5       2.7
# 124       None       None               9364   abla       5.5       2.7
# 125       None       None               9368   abla       3.6       2.0
# 126       None       None               9369   abla       3.0       1.6
# 127       None       None               9370   unkn       6.9       3.4
# 128       None       None               5667   abla       4.7       1.7
# 129       None       None               9371   abla       5.2       2.6
# 130       None       None               9366   abla      39.4      11.3
# 131       None       None               9372   abla     141.3      99.9
# 132       None       None               9380   abla     141.7      43.4
# 133       None       None               5623   pien       5.1       2.2
# 134       None       None               5666   abla      50.3      27.2
# 135       None       None               9379   pien      53.7      16.9
# 136       None       None               9382   abla       4.5       2.3
# 137       None       None               9383   abla      11.0       9.4
# 138       None       None               5637   abLA       7.3       3.4
# 139       None       None               5638   abLA      13.6       7.7
# 140       None       None               5640   abla       2.3       1.4
# 141       None       None               5639   abla     141.3      99.9
# 142       None       None               5641   abla      28.5      14.2
# 143       None       None               5642   abla       9.7       8.4
# 144       None       None               5644   abla       6.6       5.0
# 145       None       None               5645   abla       4.9       2.1
# 146       None       None               5643   abla      13.2       8.5
# 147       None       None               5954   pieN       4.2       2.7
# 148       None       None               9557   abla       2.9       1.2
# 149       None       None               9555   None      12.1      10.3
# 150       None       None               5908   None      10.2       4.2
# 151       None       None               5907   None       6.7       4.1
# 104        Postprocessed Code    Geo 7X  2021-06-14  01:20:23pm        New
# 105        Postprocessed Code    Geo 7X  2021-06-14  01:22:01pm        New
# 106        Postprocessed Code    Geo 7X  2021-06-14  01:23:24pm        New
# 107        Postprocessed Code    Geo 7X  2021-06-14  01:25:54pm        New
# 108        Postprocessed Code    Geo 7X  2021-06-14  01:27:47pm        New
# 109        Postprocessed Code    Geo 7X  2021-06-14  01:31:18pm        New
# 110        Postprocessed Code    Geo 7X  2021-06-14  01:35:32pm        New
# 111        Postprocessed Code    Geo 7X  2021-06-14  01:40:04pm        New
# 112        Postprocessed Code    Geo 7X  2021-06-14  01:42:41pm        New
# 113        Postprocessed Code    Geo 7X  2021-06-14  01:44:52pm        New
# 114        Postprocessed Code    Geo 7X  2021-06-14  01:46:46pm        New
# 115        Postprocessed Code    Geo 7X  2021-06-14  01:48:41pm        New
# 116        Postprocessed Code    Geo 7X  2021-06-14  01:51:53pm        New
# 117        Postprocessed Code    Geo 7X  2021-06-14  01:54:45pm        New
# 118        Postprocessed Code    Geo 7X  2021-06-14  01:55:44pm        New
# 119        Postprocessed Code    Geo 7X  2021-06-14  01:57:44pm        New
# 120        Postprocessed Code    Geo 7X  2021-06-14  02:00:44pm        New
# 121        Postprocessed Code    Geo 7X  2021-06-14  02:03:22pm        New
# ...
# 41   -106.869270767        22  XX-PLN2  POINT (337798.323 4302194.341)
# 42   -106.869255744        23  XX-PLN2  POINT (337799.652 4302195.538)
# 43   -106.869297925        24  XX-PLN2  POINT (337795.908 4302191.555)
# 44   -106.868947277         1  XX-PLN2  POINT (337826.410 4302194.479)
# 45   -106.869021735         2  XX-PLN2  POINT (337820.050 4302199.584)
# 46   -106.868990638         3  XX-PLN2  POINT (337822.771 4302200.633)
# 47   -106.868951877         4  XX-PLN2  POINT (337826.163 4302201.930)
# 48   -106.868964365         5  XX-PLN2  POINT (337824.965 4302196.345)
# 49   -106.869022507         6  XX-PLN2  POINT (337819.961 4302198.509)
# 50   -106.869052900         7  XX-PLN2  POINT (337817.286 4302196.701)
# 51   -106.869043104         8  XX-PLN2  POINT (337818.147 4302197.221)
# 52   -106.869098362         9  XX-PLN2  POINT (337813.403 4302199.820)
# 53   -106.869145456        10  XX-PLN2  POINT (337809.276 4302197.975)
# 54   -106.869115950        11  XX-PLN2  POINT (337811.934 4302202.685)
# 55   -106.869111106        12  XX-PLN2  POINT (337812.402 4302204.998)
# 56   -106.869062046        13  XX-PLN2  POINT (337816.656 4302204.738)
# 57   -106.869020478        14  XX-PLN2  POINT (337820.289 4302205.916)
# 58   -106.869018949        15  XX-PLN2  POINT (337820.428 4302206.249)
# 59   -106.869037158        16  XX-PLN2  POINT (337818.948 4302211.144)
# 60   -106.869028946        17  XX-PLN2  POINT (337819.601 4302208.215)
# 61   -106.868993582        18  XX-PLN2  POINT (337822.661 4302207.729)
# 62   -106.868960025        19  XX-PLN2  POINT (337825.649 4302211.357)
# 63   -106.868958195        20  XX-PLN2  POINT (337825.741 4302208.103)
# 64   -106.868905351        21  XX-PLN2  POINT (337830.266 4302205.025)
# 65   -106.868999907        22  XX-PLN2  POINT (337822.135 4302208.843)
# 66   -106.868927592        23  XX-PLN2  POINT (337828.433 4302209.826)
# 67   -106.868982459        24  XX-PLN2  POINT (337823.704 4302211.480)
# 68   -106.869035738        25  XX-PLN2  POINT (337819.130 4302214.006)
# 69   -106.868938029        26  XX-PLN2  POINT (337827.535 4302210.198)
# 70   -106.868988919        27  XX-PLN2  POINT (337823.154 4302212.012)
# 71   -106.868989376        28  XX-PLN2  POINT (337823.286 4302220.431)
# 72   -106.869012944        29  XX-PLN2  POINT (337821.125 4302214.792)
# 73   -106.869093111        30  XX-PLN2  POINT (337814.164 4302214.749)
# 74   -106.869007673        31  XX-PLN2  POINT (337821.616 4302216.444)
# 75   -106.869072476        32  XX-PLN2  POINT (337816.052 4302219.450)
# 76   -106.869024302        33  XX-PLN2  POINT (337820.221 4302218.833)
# 77   -106.868973089        34  XX-PLN2  POINT (337824.706 4302220.693)
# 78   -106.868953479        35  XX-PLN2  POINT (337826.314 4302216.096)
# 79   -106.869378363         1  XX-PLN2  POINT (337789.485 4302218.906)
# 80   -106.869367324         2  XX-PLN2  POINT (337790.390 4302216.318)
# 81   -106.869356808         3  XX-PLN2  POINT (337791.252 4302213.821)
# 82   -106.869399148         4  XX-PLN2  POINT (337787.644 4302217.135)
# 83   -106.869412525         5  XX-PLN2  POINT (337786.464 4302216.224)
# 84   -106.869432269         6  XX-PLN2  POINT (337784.791 4302218.216)
# 85   -106.869385450         7  XX-PLN2  POINT (337788.729 4302212.042)
# 86   -106.869404160         8  XX-PLN2  POINT (337787.179 4302215.685)
# 87   -106.869398180         9  XX-PLN2  POINT (337787.623 4302211.996)
# 88   -106.869442132        10  XX-PLN2  POINT (337783.917 4302217.336)
# 89   -106.869370673        11  XX-PLN2  POINT (337789.993 4302211.111)
# 90   -106.869451350        12  XX-PLN2  POINT (337783.020 4302212.622)
# 91   -106.869432949        13  XX-PLN2  POINT (337784.719 4302217.580)
# 92   -106.869421692        14  XX-PLN2  POINT (337785.547 4302210.290)
# 93   -106.869409081        15  XX-PLN2  POINT (337786.717 4302213.996)
# 94   -106.869427453        16  XX-PLN2  POINT (337785.039 4302209.905)
# 95   -106.869379871        17  XX-PLN2  POINT (337789.090 4302206.008)
# 96   -106.869463562        18  XX-PLN2  POINT (337781.902 4302209.831)
# 97   -106.869359815        19  XX-PLN2  POINT (337790.816 4302205.300)
# 98   -106.869438510        20  XX-PLN2  POINT (337783.970 4302204.578)
# 99   -106.869437996        21  XX-PLN2  POINT (337783.962 4302202.007)
# 100  -106.869449957        22  XX-PLN2  POINT (337783.032 4302207.325)
# 101  -106.869433765        23  XX-PLN2  POINT (337784.358 4302203.445)
# 102  -106.869517604        24  XX-PLN2  POINT (337777.059 4302202.408)
# 103  -106.869498019        25  XX-PLN2  POINT (337778.743 4302201.614)
# 228  -106.869221927        41  XX-PLN2  POINT (337802.906 4302211.087)
# 229  -106.869198913        42  XX-PLN2  POINT (337804.829 4302207.442)
# 230  -106.869076281         1  XX-PLN2  POINT (337814.885 4302178.611)
# 231  -106.869114123         2  XX-PLN2  POINT (337811.711 4302184.008)
# 232  -106.869087257         3  XX-PLN2  POINT (337814.064 4302185.021)
# 233  -106.869139716         4  XX-PLN2  POINT (337809.453 4302182.278)
# 234  -106.869098608         5  XX-PLN2  POINT (337813.126 4302187.364)
# 235  -106.869081764         6  XX-PLN2  POINT (337814.666 4302191.143)
# 236  -106.869032178         7  XX-PLN2  POINT (337819.028 4302193.935)
# 237  -106.869058670         8  XX-PLN2  POINT (337816.748 4302194.899)
# 238  -106.869102562         9  XX-PLN2  POINT (337812.874 4302191.834)
# 239  -106.869036862        10  XX-PLN2  POINT (337818.533 4302189.628)
# 240  -106.869014129        11  XX-PLN2  POINT (337820.454 4302187.038)
# 241  -106.869054556        12  XX-PLN2  POINT (337816.865 4302183.171)
# 242  -106.869073913        13  XX-PLN2  POINT (337815.310 4302189.320)
# 243  -106.869009528        14  XX-PLN2  POINT (337820.962 4302192.346)
# 244  -106.869031013        15  XX-PLN2  POINT (337819.135 4302194.239)
# 245  -106.868968847        16  XX-PLN2  POINT (337824.517 4302193.480)
# 246  -106.868898330        17  XX-PLN2  POINT (337830.530 4302188.142)
# 247  -106.868986271        18  XX-PLN2  POINT (337822.909 4302188.828)
# 248  -106.868938380        19  XX-PLN2  POINT (337826.985 4302184.854)
# 249  -106.869058110        20  XX-PLN2  POINT (337816.679 4302189.155)
# 250  -106.869048950        21  XX-PLN2  POINT (337817.376 4302184.370)
# 251  -106.869045357        22  XX-PLN2  POINT (337817.555 4302177.879)
# 252  -106.868977119        23  XX-PLN2  POINT (337823.569 4302182.257)
# 253  -106.869003680        24  XX-PLN2  POINT (337821.204 4302179.375)
# 254  -106.869135676        25  XX-PLN2  POINT (337809.714 4302177.889)
# 255  -106.869135085        26  XX-PLN2  POINT (337809.764 4302177.824)
# 256  -106.869119181        27  XX-PLN2  POINT (337811.278 4302184.327)
# 257  -106.869127161        28  XX-PLN2  POINT (337810.575 4302183.825)
# 258  -106.869072420        29  XX-PLN2  POINT (337815.274 4302181.197)
# 259  -106.868994205        30  XX-PLN2  POINT (337822.197 4302187.722)

# %%
clean_list = []
for i in range(len(invsheets)):
    print(idxs[i])
    result=cleansf(geodfs[i], invsheets[i])
    clean_list.append(result)
# Out:
# 2
# 3
# 4
# 5
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-cf69c2465884> in <module>
#       2 for i in range(len(invsheets)):
#       3     print(idxs[i])
# ----> 4     result=cleansf(geodfs[i], invsheets[i])
#       5     clean_list.append(result)
#
# <ipython-input-18-07397c3ee988> in cleansf(geodf, invsheet_id)
#      37     for targtag, reftag, dirc, dist in zip(targtags, reftags, dirs, dists):
#      38         if (pd.notnull(dirc) | pd.notnull(dist)):
# ---> 39             newpoint = makenewpoint(merged, reftag, targtag, dirc, dist)
#      40             newpoints_ls.append(newpoint)
#      41
#
# <ipython-input-17-b5075dee5567> in makenewpoint(associationdf, reftag, targtag, direction, distance)
#      60
#      61     # Create a new temp gpdf from new geometries
# ---> 62     new_gdf = gpd.GeoDataFrame(geometry = gpd.points_from_xy(x_prime, y_prime, crs = 'epsg:32612'))
#      63     new_gdf['Tag_Number'] = targtag
#      64     new_gdf['Comment'] = 'Point generated post-campaign from geotag association note'
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/geopandas/array.py in points_from_xy(x, y, z, crs)
#     251     output : GeometryArray
#     252     """
# --> 253     return GeometryArray(vectorized.points_from_xy(x, y, z), crs=crs)
#     254
#     255
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/geopandas/array.py in __init__(self, data, crs)
#     279
#     280         self._crs = None
# --> 281         self.crs = crs
#     282
#     283     @property
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/geopandas/array.py in crs(self, value)
#     298     def crs(self, value):
#     299         """Sets the value of the crs"""
# --> 300         self._crs = None if not value else CRS.from_user_input(value)
#     301
#     302     def check_geographic_crs(self, stacklevel):
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/pyproj/crs/crs.py in from_user_input(value, **kwargs)
#     438         if isinstance(value, CRS):
#     439             return value
# --> 440         return CRS(value, **kwargs)
#     441
#     442     def get_geod(self) -> Optional[Geod]:
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/pyproj/crs/crs.py in __init__(self, projparams, **kwargs)
#     294             projstring = _prepare_from_string(" ".join((projstring, projkwargs)))
#     295
# --> 296         super().__init__(projstring)
#     297
#     298     @staticmethod
#
# pyproj/_crs.pyx in pyproj._crs._CRS.__init__()
#
# ~/.pyenv/versions/eastriver/lib/python3.8/site-packages/pyproj/compat.py in pystrdecode(cstr)
#      20     Decode a string to a python string.
#      21     """
# ---> 22     try:
#      23         return cstr.decode("utf-8")
#      24     except AttributeError:
#
# KeyboardInterrupt:

# %%
clean_list[4]

# %%
clean_list[4].plot()

# %%
for i in range(len(geodfs)):
    print('original:', geodfs[i].shape)
    print('post:', clean_list[i].shape)

# %% [markdown]
# ---
# ## Assemble cleaned dataframes into list and export shapefiles

# %%
# Check CRS match
[clean_list[i].crs == clean_list[i+1].crs for i in np.arange(len(clean_list)-1)]

# %%
for i in clean_list:
    outpath = os.path.join(out_dir, 'Kueppers_EastRiver_Stem_Geolocations_WGS84UTM13N', i['Site'][0]+'_Stem_Geolocations_WGS84UTM13N.shp')
    i.to_file(outpath)

# %%
for i in clean_list:
    outpath = os.path.join(source_dir, 'TreeCoords', i['Site'][0]+'_Stem_Geolocations_WGS84UTM13N.csv')
    i.to_csv(outpath)

# %%
for i in os.listdir(os.path.join(out_dir, 'Kueppers_EastRiver_Stem_Geolocations_WGS84UTM13N')):
    if '.shp' in i:
        gdf = gpd.read_file(os.path.join(out_dir, 'Kueppers_EastRiver_Stem_Geolocations_WGS84UTM13N', i))
        outpath = os.path.join(source_dir, 'TreeCoords', i[:-4]+'.csv')
        gdf.to_csv(outpath)
